# %% [markdown]
# # Week 8 — Red-Teaming
#
# **LLMs & You · Hampden-Sydney College · Fall 2026**
#
# The midterm opens. Fall Break takes Tuesday, so this is a single long working session and it needs no advance reading.
#
# ---
#
# ## This is not a worksheet
#
# Nothing to hand in on Wednesday night. Work through what interests you, change
# the inputs, and find **one thing worth showing on Thursday** — ideally something
# that broke or surprised you.
#
# You can do all of this without writing code if you would rather: paste a section
# into a chatbot, ask it to explain the output or modify it for a question you
# have, and bring what you found. That is a legitimate way to work through this.
#
# Runs in Google Colab in your browser. Nothing to install.

# %% [markdown]
# !!! warning "This notebook is a draft"
#
#     The structure below is settled; the worked code is not written yet. It will
#     be finished and announced in the changelog before the session. If you are
#     reading this well before Week 8, that is why.

# %% [markdown]
# ---
# ## 0. Setup
#
# One cell, once per session. Colab forgets everything when you close the tab.

# %%
# Most of today happens at hackaprompt.com, in the browser.
# This notebook is for recording and analysing what you find there.

import numpy as np
import pandas as pd

# %% [markdown]
# ---
# ## 1. Logging attempts as you go
#
# A structured record of what you tried and what happened, because the write-up is what is graded and reconstructing it later does not work.

# %%
# TODO(w08-thu): Logging attempts as you go

# %% [markdown]
# !!! tip "Your turn"
#
#     *(Questions for this section are still being written.)*

# %% [markdown]
# ---
# ## 2. Categorising what worked
#
# Group your successful attacks. The categories you invent are the interesting output.

# %%
# TODO(w08-thu): Categorising what worked

# %% [markdown]
# !!! tip "Your turn"
#
#     *(Questions for this section are still being written.)*

# %% [markdown]
# ---
# ## 3. The defence you would build
#
# For your most effective attack. Then attack your own defence.

# %%
# TODO(w08-thu): The defence you would build

# %% [markdown]
# !!! tip "Your turn"
#
#     *(Questions for this section are still being written.)*

# %% [markdown]
# ---
# ## What to bring on Thursday
#
# One finding. A claim plus the evidence you ran, in three sentences:
#
# > *I expected X. I ran Y. I got Z, which surprised me because…*
#
# A method that broke is worth more than one that worked — the labs are graded on
# the write-up, not the result. A confusion you can state precisely counts too.
#
# <small>Questions before Thursday: sgleason@hsc.edu, or office hours T/Th 12–2.</small>
